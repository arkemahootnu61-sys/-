# %%
#pandas数据分析还有处理
import pandas as pd
df = pd.read_csv("sample_data.csv")
#head可以指定数据，比如10就是指定前10条数据，默认前五条
df.head(10)
# Out:
#     姓名  年龄  城市     工资        入职日期   部门  绩效评分 是否在职
# 0   张三  28  北京  15000  2020-03-15  技术部  88.5    是
# 1   李四  35  上海  22000  2018-07-22  产品部  92.0    是
# 2   王五  42  广州  18000  2016-01-10  市场部  76.3    否
# 3   赵六  26  深圳  13000  2022-06-01  技术部  85.0    是
# 4   孙七  31  北京  20000  2019-11-05  技术部  90.2    是
# 5   周八  38  上海  25000  2017-04-18  产品部  95.0    是
# 6   吴九  29  杭州  16000  2021-02-28  市场部  79.8    是
# 7   郑十  45  北京  28000  2015-08-14  技术部  88.0    否
# 8  冯十一  33  深圳  19000  2020-09-09  市场部  82.5    是
# 9  陈十二  27  广州  14000  2022-12-01  产品部  87.3    是

# %%
df.info()#查看信息
df.index
df.columns
df.dtypes
df.values
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   姓名      20 non-null     str
#  1   年龄      20 non-null     int64
#  2   城市      20 non-null     str
#  3   工资      20 non-null     int64
#  4   入职日期    20 non-null     str
#  5   部门      20 non-null     str
#  6   绩效评分    20 non-null     float64
#  7   是否在职    20 non-null     str
# dtypes: float64(1), int64(2), str(5)
# memory usage: 1.4 KB
# array([['张三', 28, '北京', 15000, '2020-03-15', '技术部', 88.5, '是'],
#        ['李四', 35, '上海', 22000, '2018-07-22', '产品部', 92.0, '是'],
#        ['王五', 42, '广州', 18000, '2016-01-10', '市场部', 76.3, '否'],
#        ['赵六', 26, '深圳', 13000, '2022-06-01', '技术部', 85.0, '是'],
#        ['孙七', 31, '北京', 20000, '2019-11-05', '技术部', 90.2, '是'],
#        ['周八', 38, '上海', 25000, '2017-04-18', '产品部', 95.0, '是'],
#        ['吴九', 29, '杭州', 16000, '2021-02-28', '市场部', 79.8, '是'],
# ...

# %%
data = {"country":["aaa","bbb","ccc"],
        "population":["aaa","bbb","ccc"]}
df_data = pd.DataFrame(data)
df_data
df_data.info
df_data.columns
#取指定的数据s
df_data["country"]
df_data["population"]
feng = df_data["country"]

# %%
#series:dataframe中的一部分
#df.set_index("population")
df.set_index("部门")
age = df["年龄"]
#age["23"]
age = age + 10
age
age = age * 10
age
age.mean()
age.min()
age.max()
#可以得到数据基本的统计特性
df.describe()
# Out:
#               年龄            工资       绩效评分
# count  20.000000     20.000000  20.000000
# mean   33.400000  19175.000000  86.360000
# std     6.235721   4848.426223   5.372875
# min    25.000000  12500.000000  76.300000
# 25%    28.000000  15375.000000  82.175000
# 50%    32.500000  18500.000000  87.550000
# 75%    38.250000  22500.000000  90.400000
# max    45.000000  28000.000000  95.000000
